# %% [markdown]
# 1. ¿Cómo facilitan las funciones la automatizacion del analisis ambienta?
#    Las funciones permiten realizar un proceso de analisis de datos ambientales de forma automatizada y organizada empleando herraminetas que minimizan el uso repetido de codigos y por el contrario reutilizan estos para realizar el análisis de diferentes parámetros a estudiar, este proceso limita los errores y disminuye el tiempo de trabajo.
# 2. ¿Qué ventajas tiene modularizar el código mediante def y apply()?
#    el uso de estas dos herraminetas permite evitar tener un codigo repetitivo que genere un aspecto mas desordenado en el código, reducen los errores y hacen que el código sea mas facil de leer; el uso de des y apply() permite agilizar la evaluación de varios parámetros a estudiar y clasificar los resultados obtenidos de forma coherente. En el cado de def lo que se hace es definir funciones mientras que apply() para aplicarlas en las estructuras.
# 3. ¿Qué aprendieron del trabajo colaborativo con GitHub Clasroom?
#    El trabajo colaborativo mediante la plataforma de GitHub permitió que cada integrante se esforzara por trabajar de forma organizada y conjunta, tambien se reconoció la importancia de realizar una revisión  y verificación de todos los resultados obtenidos en el proyecto. se fortalecieron las habilidades en el manejo de herramientas básicas para la programación de códigos utiles en el entorno de analisis ambientales.
